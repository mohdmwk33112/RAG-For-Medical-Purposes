# %%
# !pip install chromadb

# %%
import chromadb
client = chromadb.PersistentClient(path="./database.sqlite")

# %%
import pandas as pd

# %%
db=pd.read_csv("./drugs_side_effects_drugs_com.csv")
db.head()
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
# !pip install google-auth google-api-python-client
# Out:
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB 1.3 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/12.7 MB 787.7 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/12.7 MB 1.1 MB/s eta 0:00:12
#     --------------------------------------- 0.2/12.7 MB 1.1 MB/s eta 0:00:12
#     --------------------------------------- 0.3/12.7 MB 1.1 MB/s eta 0:00:12
#     --------------------------------------- 0.3/12.7 MB 1.2 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/12.7 MB 1.1 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/12.7 MB 1.2 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/12.7 MB 1.2 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/12.7 MB 1.2 MB/s eta 0:00:11
#    - -------------------------------------- 0.6/12.7 MB 1.2 MB/s eta 0:00:11
# ...

# %%
db.shape
# Out:
# (2931, 17)

# %%
db_clean = db.dropna()

# %%
db_clean.shape
# Out:
# (251, 17)

# %%
db_clean = db.iloc[:, :6]
db_clean.shape
# Out:
# (2931, 6)

# %%
db_cleaned = db_clean.dropna()
db_cleaned.shape
# Out:
# (1692, 6)

# %%
db_cleaned.head()
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 4     clindamycin              Acne
# 5       Aldactone              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
# 5  hives ; difficulty breathing; swelling of your...       spironolactone
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 4       Topical acne agents, Vaginal anti-infectives
# ...

# %%
# import

# !pip install google-generativeai
# Out:
# ...
#    ---------------------------------------- 0.0/160.8 kB ? eta -:--:--
#    ------- -------------------------------- 30.7/160.8 kB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 92.2/160.8 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 160.8/160.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/760.0 kB ? eta -:--:--
#    ---------- ----------------------------- 194.6/760.0 kB 3.9 MB/s eta 0:00:01
#    ------------------ --------------------- 358.4/760.0 kB 4.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 532.5/760.0 kB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 716.8/760.0 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 760.0/760.0 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import chromadb.utils.embedding_functions as embedding_functions

# use directlye 
google_ef  = embedding_functions.GoogleGenerativeAiEmbeddingFunction(api_key="AIzaSyApEcCRCZRLR8pO1qKM68MOP5e9CtTUlTM")

# pass documents to query for .add and .query
collection = client.get_or_create_collection(name="medicine", embedding_function=google_ef)

# %%
documents = []
for index, row in db_cleaned.iterrows():
    if index == 0:
        continue
    documents.append("the drug name is "+row[0]+" and the medical condition to take the drug is "+row[1]+" and its side effect is "+row[2]+" and its generic name is "+row[3]+" this drug classes is "+row[4]+" and its brand name is "+row[5])

for i in range(5):
    print(documents[i])
# Out:
# the drug name is spironolactone and the medical condition to take the drug is Acne and its side effect is hives ; difficulty breathing; swelling of your face, lips, tongue, or throat. Call your doctor at once if you have: a light-headed feeling, like you might pass out; little or no urination; high potassium level - nausea , weakness, tingly feeling, chest pain, irregular heartbeats, loss of movement; o signs of other electrolyte imbalances - increased thirst or urination, confusion, vomiting , muscle pain, slurred speech, severe weakness, numbness , loss of coordination, feeling unsteady. Common spironolactone side effects may include: breast swelling or tenderness. and its generic name is spironolactone this drug classes is Aldosterone receptor antagonists, Potassium-sparing diuretics and its brand name is Aldactone, CaroSpir
# ...

# %%
id = 0
for index in range(len(documents)):
    if index == 0:
        continue
    
    collection.add(
        documents=documents[id],
        ids=[str(id)]
    )
    id = id + 1
print("Data successfully added to ChromaDB!")
# Out:
# Insert of existing embedding ID: 0
# Add of existing embedding ID: 0
# Insert of existing embedding ID: 1
# Add of existing embedding ID: 1
# Insert of existing embedding ID: 2
# Add of existing embedding ID: 2
# Insert of existing embedding ID: 3
# Add of existing embedding ID: 3
# Insert of existing embedding ID: 4
# Add of existing embedding ID: 4
# Insert of existing embedding ID: 5
# Add of existing embedding ID: 5
# Insert of existing embedding ID: 6
# Add of existing embedding ID: 6
# Insert of existing embedding ID: 7
# Add of existing embedding ID: 7
# Insert of existing embedding ID: 8
# Add of existing embedding ID: 8
# Insert of existing embedding ID: 9
# Add of existing embedding ID: 9
# Insert of existing embedding ID: 13
# Add of existing embedding ID: 13
# Insert of existing embedding ID: 14
# Add of existing embedding ID: 14
# Insert of existing embedding ID: 15
# Add of existing embedding ID: 15
# Insert of existing embedding ID: 16
# ...

# %%
from pprint import pprint
results = collection.query(
    query_texts=["clindamycin"], # Chroma will embed this for you
    n_results=2 # how many results to return
)
pprint(results)
# Out:
# {'data': None,
#  'distances': [[0.39098626375198364, 0.4075682759284973]],
#  'documents': [['the drug name is clindamycin and the medical condition to '
#                 'take the drug is Acne and its side effect is hives ; '
#                 'difficult breathing; swelling of your face, lips, tongue, or '
#                 'throat. Clindamycin topical may cause serious side effects. '
#                 'Stop using clindamycin topical and call your doctor at once '
#                 'if you have: severe redness, itching, or dryness of treated '
#                 'skin areas; or severe stomach pain, diarrhea that is watery '
#                 'or bloody (even if it occurs months after your last dose). '
#                 'Common side effects of clindamycin topical may include: '
#                 'burning, itching, dryness, peeling or redness of treated '
#                 'skin; or oily skin. and its generic name is clindamycin '
# ...

# %%
index = 593
for index in range(len(documents)):
    
    collection.add(
        documents=documents[id],
        ids=[str(id)]
    )
    id = id + 1
print("Data successfully added to ChromaDB!")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# File C:\coding\Anaconda\Lib\site-packages\chromadb\api\models\CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      89 try:
# ---> 90     return func(self, *args, **kwargs)
#      91 except Exception as e:
#
# File C:\coding\Anaconda\Lib\site-packages\chromadb\api\models\CollectionCommon.py:213, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     212     validate_record_set_for_embedding(record_set=add_records)
# --> 213     add_embeddings = self._embed_record_set(record_set=add_records)
#     214 else:
#
# File C:\coding\Anaconda\Lib\site-packages\chromadb\api\models\CollectionCommon.py:526, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields)
#     525         else:
# ...

# %%
print(id)
# Out:
# 1162

# %%
id=1163
index=1164
for index in range(len(documents)):
    
    collection.add(
        documents=documents[id],
        ids=[str(id)]
    )
    id = id + 1
print("Data successfully added to ChromaDB!")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 6
#       2 index=1164
#       3 for index in range(len(documents)):
#       5     collection.add(
# ----> 6         documents=documents[id],
#       7         ids=[str(id)]
#       8     )
#       9     id = id + 1
#      10 print("Data successfully added to ChromaDB!")
#
# IndexError: list index out of range

# %%
print(id)
# Out:
# 1691

# %%
query = "what is the difference between Epivir and Cleocin T"
results = collection.query(
    query_texts=[query], # Chroma will embed this for you
    n_results=29 # how many results to return
)
pprint(results)
# Out:
# {'data': None,
#  'distances': [[0.466360867023468,
#                 0.46926388144493103,
#                 0.4946543574333191,
#                 0.4991014003753662,
#                 0.4997747540473938,
#                 0.5014333128929138,
#                 0.5084071755409241,
#                 0.5128938555717468,
#                 0.5150499939918518,
#                 0.5172728300094604,
#                 0.5173572301864624,
#                 0.5187990665435791,
#                 0.522634744644165,
#                 0.5230454802513123,
#                 0.5242173671722412,
#                 0.5281730890274048,
#                 0.5306572914123535,
#                 0.53273606300354,
#                 0.5362963080406189,
#                 0.5363438725471497,
#                 0.5369106531143188,
#                 0.537795901298523,
#                 0.5380064249038696,
#                 0.5390477180480957,
#                 0.5393893122673035,
# ...

# %%
import google.generativeai as genai

# %%
# Replace with your Gemini API key
api_key = ""

# Configure Gemini
genai.configure(api_key=api_key)
model = genai.GenerativeModel("gemini-pro")

# %%
retrieved_docs = results['documents'][0]  # Retrieved documents
safe_docs = [doc for doc in retrieved_docs if "misuse" not in doc and "illegal" not in doc]
print("Retrieved Documents:", safe_docs)
# Out:
# Retrieved Documents: ["the drug name is Epivir-HBV and the medical condition to take the drug is AIDS/HIV and its side effect is hives ; difficult breathing; swelling of your face, lips, tongue, or throat. Mild symptoms of lactic acidosis may worsen over time , and this condition can be fatal. Get emergency medical help if you have: unusual muscle pain, trouble breathing, stomach pain, vomiting , irregular heart rate, dizziness , feeling cold, or feeling very weak or tired. Epivir HBV may cause serious side effects. Call your doctor at once if you have: pancreas problems--severe pain in your upper stomach spreading to your back, nausea and vomiting , fast heart rate ; or liver problems--swelling around your midsection, right-sided upper stomach pain, loss of appetite, dark urine, clay-colored stools, jaundice (yellowing of the skin or eyes). Epivir HBV affects your immune system, which may cause certain side effects (even weeks or months after you've taken Epivir HBV). Tell your doct
# ...

# %%
# Combine the query and retrieved context
context = "\n".join(safe_docs)
full_prompt = f"""
Disclaimer: The following is for educational purposes only. Consult a licensed healthcare professional for medical advice.

Context:
{context}

Query:
{query}
"""

# Generate answer with Gemini
response = model.generate_content(
    full_prompt,
    safety_settings=[
        {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "HIGH"}
    ]
)

print("Generated Answer:", response.text)
# Out:
# Generated Answer: Epivir is used to treat AIDS/HIV while Cleocin T is used to treat Acne. Epivir's side effects include hives, difficulty breathing, swelling of the face, lips, tongue, or throat, unusual muscle pain, trouble breathing, stomach pain, vomiting , irregular heart rate, dizziness , feeling cold, or feeling very weak or tired. Cleocin T's side effects include hives, difficulty breathing, swelling of the face, lips, tongue, or throat, severe redness, itching, or dryness of treated skin areas, and severe stomach pain, diarrhea that is watery or bloody (even if it occurs months after your last dose).

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 print(documents[1000])
#
# NameError: name 'documents' is not defined
